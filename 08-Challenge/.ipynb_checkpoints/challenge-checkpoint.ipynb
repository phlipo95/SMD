# %%
#Header
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
#Read Data

train = pd.read_csv("train.csv", index_col=False).to_dict() 
print(train.keys())
train?
print(train['Electrical'])
# Out:
# dict_keys(['Electrical', 'BsmtQual', 'ExterCond', '1stFlrSF', 'LotConfig', 'BsmtExposure', 'SalePrice', 'LowQualFinSF', 'FullBath', 'TotalBsmtSF', 'BsmtFinType1', 'ScreenPorch', 'Neighborhood', 'BsmtFullBath', 'HalfBath', 'FireplaceQu', 'BldgType', 'GarageQual', 'BsmtCond', 'WoodDeckSF', 'MasVnrType', 'RoofMatl', 'Functional', 'OverallCond', 'RoofStyle', 'KitchenAbvGr', 'SaleCondition', 'OverallQual', 'LotShape', 'Fence', 'HeatingQC', 'EnclosedPorch', 'GarageType', 'Exterior1st', 'BsmtFinType2', 'BsmtFinSF1', 'Exterior2nd', 'MiscVal', 'GarageArea', 'GarageCond', 'Condition2', 'PoolQC', 'Heating', 'GarageFinish', 'TotRmsAbvGrd', 'OpenPorchSF', 'SaleType', 'LotArea', 'LandContour', 'KitchenQual', 'GrLivArea', 'LotFrontage', 'MoSold', 'YrSold', 'BsmtFinSF2', 'LandSlope', 'BsmtHalfBath', 'MiscFeature', 'GarageCars', 'BsmtUnfSF', 'MSSubClass', 'GarageYrBlt', 'BedroomAbvGr', 'Id', 'CentralAir', 'YearRemodAdd', 'Fireplaces', 'Utilities', 'PavedDrive', 'Street', 'MSZoning', 'ExterQual', '2nd
# ...
